# %%
#Happy coding!

"""loan_prediction.py: This program predicts whether
a person qualifies for a loan based on some factors"""

#__author__ = "Immanuella Duke"
# Out:
# 'loan_prediction.py: his program predicts whether\na person qualifies for a loan based on some factors'

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import OrdinalEncoder

# %%
loan_train_data = pd.read_csv("loan_data/train_data.csv")

# %%
loan_train_data.tail(40)
# Out:
#       Loan_ID  Gender Married Dependents  Education Self_Employed  \
# 574  LP002863    Male     Yes         3+         -1            No
# 575  LP002868    Male     Yes          2         -1            No
# 576  LP002872     NaN     Yes          0         -1            No
# 577  LP002874    Male      No          0         -1            No
# 578  LP002877    Male     Yes          1         -1            No
# 579  LP002888    Male      No          0         -1           NaN
# 580  LP002892    Male     Yes          2         -1            No
# 581  LP002893    Male      No          0         -1            No
# 582  LP002894  Female     Yes          0         -1            No
# 583  LP002898    Male     Yes          1         -1            No
# 584  LP002911    Male     Yes          1         -1            No
# 585  LP002912    Male     Yes          1         -1            No
# 586  LP002916    Male     Yes          0         -1            No
# ...

# %%
loan_train_data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#perform exploratory analysis
temp_data = loan_train_data.dropna()

plt.bar(temp_data.Married, temp_data.LoanAmount, color='y')
plt.title("Married and Loan Amount")
#people that are married ask for loans more than single people
plt.show()

plt.bar(temp_data.Education, temp_data.LoanAmount, color='r')
plt.title("Educational status and Loan Amount")
#graduates ask for loans more than people who are not graduates

plt.show()

plt.bar(temp_data.Self_Employed, temp_data.LoanAmount, color='g')
plt.title("Self-employed and Loan Amount")
#people that are self-employed ask for loans as much as people who are not
# Out:
# Text(0.5, 1.0, 'Self-employed and Loan Amount')

# %%
#perform descriptive statistics
loan_train_data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#prepare data
#ordinal data

#education
encoder = OrdinalEncoder()
education = pd.Categorical(loan_train_data.Education, 
                     categories=['missing', 'Not Graduate', 'Graduate'], 
                     ordered=True)
education.fillna('missing')
labels, unique = pd.factorize(education, sort=True)
loan_train_data.Education = labels


#nominal data
#gender
le = preprocessing.LabelEncoder()
le.fit(["Nan", "Male", "Female"])
le.transform(loan_train_data.Gender)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\immanuella duke\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\label.py in _encode_python(values, uniques, encode)
#      63         try:
# ---> 64             encoded = np.array([table[v] for v in values])
#      65         except KeyError as e:
#
# c:\users\immanuella duke\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\label.py in <listcomp>(.0)
#      63         try:
# ---> 64             encoded = np.array([table[v] for v in values])
#      65         except KeyError as e:
#
# KeyError: nan
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-5d854033333e> in <module>
#      16 le = preprocessing.LabelEncoder()
# ...

# %%
#numpy helps with faster computation
loan_data_array = loan_train_data.values
num_cols = loan_data_array.shape[1]

#leave out the loan ID
train_data_x = loan_data_array[:, 2:num_cols-1]

train_data_y = loan_data_array[:, num_cols-1]
print(train_data_x.shape)
print(train_data_y.shape)

#feature selection
#using stepwise regression to choose the most significant features
# Feature extraction
test = SelectKBest(score_func=chi2, k=4)
fit = test.fit(train_data_x, train_data_y)
